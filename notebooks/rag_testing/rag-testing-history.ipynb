# %% [markdown]
# # RAG Testing (with history) Notebook
# An isolated environment to experiment with different models and retrieval strategies. This RAG implementation does include chat history in the retrieval.
